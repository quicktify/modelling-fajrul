# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
#1
# Out:
# Note: you may need to restart the kernel to use updated packages.Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#   Using cached https://download.pytorch.org/whl/cu126/torchvision-0.22.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu126/torchaudio-2.7.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu126/torch-2.7.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (29 kB)
# ...
#   Using cached https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.3 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 2.1/6.3 MB 5.3 MB/s eta 0:00:01
#    --------------------- ------------------ 3.4/6.3 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.3 MB 6.2 MB/s eta 0:00:01
# ...
